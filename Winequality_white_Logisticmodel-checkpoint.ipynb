# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
ds=pd.read_csv('winequality-white.csv',sep=';')

# %%
ds.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
ds.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6

# %%
ds.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
# fixed acidity           4898 non-null float64
# volatile acidity        4898 non-null float64
# citric acid             4898 non-null float64
# residual sugar          4898 non-null float64
# chlorides               4898 non-null float64
# free sulfur dioxide     4898 non-null float64
# total sulfur dioxide    4898 non-null float64
# density                 4898 non-null float64
# pH                      4898 non-null float64
# sulphates               4898 non-null float64
# alcohol                 4898 non-null float64
# quality                 4898 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
ds.shape
# Out:
# (4898, 12)

# %%
ds.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# min       0.009000             2.000000              9.000000     0.987110
# 25%       0.036000            23.000000            108.000000     0.991723
# 50%       0.043000            34.000000            134.000000     0.993740
# 75%       0.050000            46.000000            167.000000     0.996100
# max       0.346000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  4898.000000  4898.000000  4898.000000  4898.000000
# mean      3.188267     0.489847    10.514267     5.877909
# std       0.151001     0.114126     1.230621     0.885639
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.090000     0.410000     9.500000     5.000000
# 50%       3.180000     0.470000    10.400000     6.000000
# 75%       3.280000     0.550000    11.400000     6.000000
# max       3.820000     1.080000    14.200000     9.000000

# %%
ds.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(ds.isnull())

# %%
ds.quality.value_counts()
# Out:
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: quality, dtype: int64

# %%
sns.countplot(x='quality',data=ds)

# %%
for i in ds.columns:
    sns.boxenplot(x=ds[i])
    print(i)
    print('\n')
    plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# fixed acidity
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# volatile acidity
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# citric acid
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# residual sugar
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# chlorides
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# free sulfur dioxide
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# total sulfur dioxide
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# density
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# pH
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# sulphates
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# alcohol
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# quality

# %%
ds.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.022697     0.289181
# volatile acidity          -0.022697          1.000000    -0.149472
# citric acid                0.289181         -0.149472     1.000000
# residual sugar             0.089021          0.064286     0.094212
# chlorides                  0.023086          0.070512     0.114364
# free sulfur dioxide       -0.049396         -0.097012     0.094077
# total sulfur dioxide       0.091070          0.089261     0.121131
# density                    0.265331          0.027114     0.149503
# pH                        -0.425858         -0.031915    -0.163748
# sulphates                 -0.017143         -0.035728     0.062331
# alcohol                   -0.120881          0.067718    -0.075729
# quality                   -0.113663         -0.194723    -0.009209
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.089021   0.023086            -0.049396
# volatile acidity            0.064286   0.070512            -0.097012
# citric acid                 0.094212   0.114364             0.094077
# residual sugar              1.000000   0.088685             0.299098
# chlorides                   0.088685   1.000000             0.101392
# free sulfur dioxide         0.299098   0.101392             1.000000
# total sulfur dioxide        0.401439   0.198910             0.615501
# density                     0.838966   0.257211             0.294210
# pH                         -0.194133  -0.090439            -0.000618
# sulphates                  -0.026664   0.016763             0.059217
# alcohol                    -0.450631  -0.360189            -0.250104
# quality                    -0.097577  -0.209934             0.008158
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                     0.091070  0.265331 -0.425858  -0.017143
# volatile acidity                  0.089261  0.027114 -0.031915  -0.035728
# citric acid                       0.121131  0.149503 -0.163748   0.062331
# residual sugar                    0.401439  0.838966 -0.194133  -0.026664
# chlorides                         0.198910  0.257211 -0.090439   0.016763
# free sulfur dioxide               0.615501  0.294210 -0.000618   0.059217
# total sulfur dioxide              1.000000  0.529881  0.002321   0.134562
# density                           0.529881  1.000000 -0.093591   0.074493
# pH                                0.002321 -0.093591  1.000000   0.155951
# sulphates                         0.134562  0.074493  0.155951   1.000000
# alcohol                          -0.448892 -0.780138  0.121432  -0.017433
# quality                          -0.174737 -0.307123  0.099427   0.053678
#
#                        alcohol   quality
# fixed acidity        -0.120881 -0.113663
# volatile acidity      0.067718 -0.194723
# citric acid          -0.075729 -0.009209
# residual sugar       -0.450631 -0.097577
# chlorides            -0.360189 -0.209934
# free sulfur dioxide  -0.250104  0.008158
# total sulfur dioxide -0.448892 -0.174737
# density              -0.780138 -0.307123
# pH                    0.121432  0.099427
# sulphates            -0.017433  0.053678
# alcohol               1.000000  0.435575
# quality               0.435575  1.000000

# %%
plt.figure(figsize=(12,10))
sns.heatmap(ds.corr(),annot=True)

# %%
ds.hist(figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D93398FB08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D934BB6148>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D934BF6588>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001D934C38048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D934122308>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D933F0B748>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001D933D6AB08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D934B7BE08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D934B6F6C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001D9324C8E88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D9324A1648>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D932536088>]],
#       dtype=object)

# %%
sns.pairplot(ds)

# %%
for i in ds.columns:
    print(i)
    sns.distplot(ds[i],bins=10)
    print('\n')
    plt.show()
# Out:
# fixed acidity
# volatile acidity
# citric acid
# residual sugar
# chlorides
# free sulfur dioxide
# total sulfur dioxide
# density
# pH
# sulphates
# alcohol
# quality

# %%
from scipy.stats import zscore
z=np.abs(zscore(ds))
print(z.shape)
ds_new=ds.loc[(abs(z)<3).all(axis=1)]
print(ds_new.shape)
# Out:
# (4898, 12)
# (4487, 12)

# %%
ds_new.skew()
# Out:
# fixed acidity           0.300262
# volatile acidity        0.749286
# citric acid             0.433297
# residual sugar          0.707584
# chlorides               1.055353
# free sulfur dioxide     0.363393
# total sulfur dioxide    0.274199
# density                 0.259895
# pH                      0.279089
# sulphates               0.646390
# alcohol                 0.445764
# quality                 0.242035
# dtype: float64

# %%
from scipy.stats import boxcox
ds_new['volatile acidity']=boxcox(ds_new['volatile acidity'])[0]
ds_new['residual sugar']=boxcox(ds_new['residual sugar'])[0]
ds_new['chlorides']=boxcox(ds_new['chlorides'])[0]
ds_new['sulphates']=boxcox(ds_new['sulphates'])[0]

# %%
ds_new.skew()
# Out:
# fixed acidity           0.300262
# volatile acidity       -0.001095
# citric acid             0.433297
# residual sugar         -0.063277
# chlorides               0.020712
# free sulfur dioxide     0.363393
# total sulfur dioxide    0.274199
# density                 0.259895
# pH                      0.279089
# sulphates               0.001352
# alcohol                 0.445764
# quality                 0.242035
# dtype: float64

# %%
x=ds_new.drop(['quality'],axis=1)
print(x.shape)
y=ds_new['quality']
print(y.shape)
# Out:
# (4487, 11)
# (4487,)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x=pd.DataFrame(x)
x.skew()
# Out:
# 0     0.300262
# 1    -0.001095
# 2     0.433297
# 3    -0.063277
# 4     0.020712
# 5     0.363393
# 6     0.274199
# 7     0.259895
# 8     0.279089
# 9     0.001352
# 10    0.445764
# dtype: float64

# %%
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,auc,roc_curve
import warnings
warnings.filterwarnings('ignore')

# %%
max_r_score=0
for r_state in range(42,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
    rg=LogisticRegression()
    rg.fit(x_train,y_train)
    pred=rg.predict(x_test)
    a_scr =accuracy_score(y_test,pred)
    if a_scr>max_r_score:
        max_r_score=a_scr
        final_r_state=r_state
print('max r2 score corresponding',final_r_state,'is',max_r_score)
# Out:
# max r2 score corresponding 56 is 0.5723830734966593

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=56,test_size=0.20)
lr=LogisticRegression()
lr.fit(x_train,y_train)
lr_pred=lr.predict(x_test)
print(accuracy_score(y_test,lr_pred))
print(classification_report(y_test,lr_pred))
print(confusion_matrix(y_test,lr_pred))
cvs=cross_val_score(lr,x,y,cv=10,scoring='accuracy').mean()
print('\n')
print(cvs)
# Out:
# 0.5723830734966593
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00        20
#            5       0.64      0.56      0.60       270
#            6       0.54      0.82      0.65       411
#            7       0.57      0.17      0.26       160
#            8       0.00      0.00      0.00        37
#
#     accuracy                           0.57       898
#    macro avg       0.35      0.31      0.30       898
# weighted avg       0.55      0.57      0.53       898
#
# [[  0  14   6   0   0]
#  [  0 152 118   0   0]
#  [  0  64 335  12   0]
#  [  0   6 127  27   0]
#  [  0   0  29   8   0]]
#
#
# 0.5287384746315296

# %%
mnb=MultinomialNB()
mnb.fit(np.abs(x_train),np.abs(y_train))
m_pred=mnb.predict(x_test)
#print(m_pred)
print('\n')
print('Accuracy_score:',accuracy_score(y_test,m_pred))
print(classification_report(y_test,m_pred))
print(confusion_matrix(y_test,m_pred))
cvsm=cross_val_score(lr,x,y,cv=10,scoring='accuracy').mean()
print('\n')
print(cvsm)
# Out:
# Accuracy_score: 0.46993318485523383
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00        20
#            5       0.48      0.21      0.29       270
#            6       0.48      0.85      0.62       411
#            7       0.29      0.10      0.15       160
#            8       0.00      0.00      0.00        37
#
#     accuracy                           0.47       898
#    macro avg       0.25      0.23      0.21       898
# weighted avg       0.42      0.47      0.40       898
#
# [[  0   3  13   4   0]
#  [  0  57 199  14   0]
#  [  0  44 349  18   0]
#  [  0  12 132  16   0]
#  [  0   3  30   4   0]]
#
#
# 0.5287384746315296

# %%
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
dtc.score(x_train,y_train)
dtc_pred=dtc.predict(x_test)
print(accuracy_score(y_test,m_pred))
print(classification_report(y_test,m_pred))
print(confusion_matrix(y_test,m_pred))
cvsdt=cross_val_score(lr,x,y,cv=5,scoring='accuracy').mean()
print('\n')
print(cvsdt)
# Out:
# 0.46993318485523383
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00        20
#            5       0.48      0.21      0.29       270
#            6       0.48      0.85      0.62       411
#            7       0.29      0.10      0.15       160
#            8       0.00      0.00      0.00        37
#
#     accuracy                           0.47       898
#    macro avg       0.25      0.23      0.21       898
# weighted avg       0.42      0.47      0.40       898
#
# [[  0   3  13   4   0]
#  [  0  57 199  14   0]
#  [  0  44 349  18   0]
#  [  0  12 132  16   0]
#  [  0   3  30   4   0]]
#
#
# 0.5253319726042811

# %%
models=['linear', 'poly', 'rbf', 'sigmoid']

# %%
for i in models:
    svc=SVC(kernel=i)
    svc.fit(x_train,y_train)
    svc.score(x_train,y_train)
    svc_pred=svc.predict(x_test)
    print('*******************************',i,'************************************************')
    print(accuracy_score(y_test,svc_pred))
    print(confusion_matrix(y_test,svc_pred))
    print(classification_report(y_test,svc_pred))
    cvsdt=cross_val_score(svc,x,y,cv=10,scoring='accuracy').mean()
    print('\n')
    print(cvsdt)
    print('\n')
# Out:
# ******************************* linear ************************************************
# 0.5489977728285078
# [[  0  14   6   0   0]
#  [  0 150 120   0   0]
#  [  0  68 343   0   0]
#  [  0   8 152   0   0]
#  [  0   0  37   0   0]]
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00        20
#            5       0.62      0.56      0.59       270
#            6       0.52      0.83      0.64       411
#            7       0.00      0.00      0.00       160
#            8       0.00      0.00      0.00        37
#
#     accuracy                           0.55       898
#    macro avg       0.23      0.28      0.25       898
# weighted avg       0.43      0.55      0.47       898
#
#
#
# 0.5140246818419616
#
#
# ******************************* poly ************************************************
# 0.5612472160356348
# [[  1   8  11   0   0]
#  [  0 108 156   6   0]
#  [  2  36 361  12   0]
#  [  0   6 119  34   1]
#  [  0   0  26  11   0]]
#               precision    recall  f1-score   support
#
#            4       0.33      0.05      0.09        20
#            5       0.68      0.40      0.50       270
#            6       0.54      0.88      0.67       411
#            7       0.54      0.21      0.30       160
#            8       0.00      0.00      0.00        37
#
#     accuracy                           0.56       898
#    macro avg       0.42      0.31      0.31       898
# weighted avg       0.55      0.56      0.51       898
#
#
#
# 0.5097140802903123
#
#
# ******************************* rbf ************************************************
# 0.5913140311804009
# [[  0  12   8   0   0]
#  [  0 161 107   2   0]
#  [  0  64 327  20   0]
#  [  0   5 112  43   0]
#  [  0   0  24  13   0]]
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00        20
#            5       0.67      0.60      0.63       270
#            6       0.57      0.80      0.66       411
#            7       0.55      0.27      0.36       160
#            8       0.00      0.00      0.00        37
#
#     accuracy                           0.59       898
#    macro avg       0.36      0.33      0.33       898
# weighted avg       0.56      0.59      0.56       898
#
#
#
# 0.5418834423948559
#
#
# ******************************* sigmoid ************************************************
# 0.4209354120267261
# [[  2   9   7   2   0]
#  [  7 129 121  13   0]
#  [  1 131 205  72   2]
#  [  0  28  88  40   4]
#  [  0   1  25   9   2]]
#               precision    recall  f1-score   support
#
#            4       0.20      0.10      0.13        20
#            5       0.43      0.48      0.45       270
#            6       0.46      0.50      0.48       411
#            7       0.29      0.25      0.27       160
#            8       0.25      0.05      0.09        37
#
#     accuracy                           0.42       898
#    macro avg       0.33      0.28      0.29       898
# weighted avg       0.41      0.42      0.41       898
#
#
#
# 0.45402866047052876

# %%
svc=SVC(kernel='poly')
svc.fit(x_train,y_train)
svc.score(x_train,y_train)
svc_pred=svc.predict(x_test)
print(accuracy_score(y_test,svc_pred))
print(confusion_matrix(y_test,svc_pred))
print(classification_report(y_test,svc_pred))
cvsdt=cross_val_score(svc,x,y,cv=10,scoring='accuracy').mean()
print('\n')
print(cvsdt)
# Out:
# 0.5612472160356348
# [[  1   8  11   0   0]
#  [  0 108 156   6   0]
#  [  2  36 361  12   0]
#  [  0   6 119  34   1]
#  [  0   0  26  11   0]]
#               precision    recall  f1-score   support
#
#            4       0.33      0.05      0.09        20
#            5       0.68      0.40      0.50       270
#            6       0.54      0.88      0.67       411
#            7       0.54      0.21      0.30       160
#            8       0.00      0.00      0.00        37
#
#     accuracy                           0.56       898
#    macro avg       0.42      0.31      0.31       898
# weighted avg       0.55      0.56      0.51       898
#
#
#
# 0.5097140802903123

# %%
def algorithm_pipeline(X_train_data, X_test_data, y_train_data, y_test_data, 
                       model, param_grid, cv=10, scoring_fit='neg_mean_squared_error',
                       do_probabilities = False):
    gs = GridSearchCV(
        estimator=model,
        param_grid=param_grid, 
        cv=cv, 
        n_jobs=-1, 
        scoring=scoring_fit,
        verbose=2
    )
    fitted_model = gs.fit(X_train_data, y_train_data)
    
    if do_probabilities:
      pred = fitted_model.predict_proba(X_test_data)
    else:
      pred = fitted_model.predict(X_test_data)
    
    return fitted_model, pred

# %%
model = RandomForestClassifier()
param_grid = {
    'n_estimators': [400, 700, 1000],
    'max_depth': [15,20,25],
    'max_leaf_nodes': [50, 100, 200]
}

model, pred = algorithm_pipeline(x_train, x_test, y_train, y_test, model, 
                                 param_grid, cv=5, scoring_fit='accuracy')

print(model.best_score_)
print(model.best_params_)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   46.1s
# [Parallel(n_jobs=-1)]: Done 135 out of 135 | elapsed:  3.3min finished
# 0.6416829200334355
# {'max_depth': 20, 'max_leaf_nodes': 200, 'n_estimators': 700}

# %%
from sklearn.model_selection import RandomizedSearchCV

def search_pipeline(X_train_data, X_test_data, y_train_data, y_test_data, 
                       model, param_grid, cv=10, scoring_fit='neg_mean_squared_error',
                       do_probabilities = False, search_mode = 'GridSearchCV', n_iterations = 0):
    fitted_model = None
    
    if(search_mode == 'GridSearchCV'):
        gs = GridSearchCV(
            estimator=model,
            param_grid=param_grid, 
            cv=cv, 
            n_jobs=-1, 
            scoring=scoring_fit,
            verbose=2
        )
        fitted_model = gs.fit(X_train_data, y_train_data)

    elif (search_mode == 'RandomizedSearchCV'):
        rs = RandomizedSearchCV(
            estimator=model,
            param_distributions=param_grid, 
            cv=cv,
            n_iter=n_iterations,
            n_jobs=-1, 
            scoring=scoring_fit,
            verbose=2
        )
        fitted_model = rs.fit(X_train_data, y_train_data)
    
    
    if(fitted_model != None):
        if do_probabilities:
            pred = fitted_model.predict_proba(X_test_data)
        else:
            pred = fitted_model.predict(X_test_data)
            
        return fitted_model, pred

# %%
model = RandomForestClassifier()
param_grid = {
    'n_estimators': [400, 700, 1000],
    'max_depth': [15,20,25],
    'max_leaf_nodes': [50, 100, 200]
}

model, pred = search_pipeline(x_train, x_test, y_train, y_test, model, 
                                 param_grid, cv=5, scoring_fit='accuracy')

print(model.best_score_)
print(model.best_params_)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   45.3s
# [Parallel(n_jobs=-1)]: Done 135 out of 135 | elapsed:  3.3min finished
# 0.6433546949010867
# {'max_depth': 20, 'max_leaf_nodes': 200, 'n_estimators': 700}
