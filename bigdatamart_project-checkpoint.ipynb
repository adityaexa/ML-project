# %%
import pandas as pd 
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.externals import joblib
import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
ds_train =pd.read_csv('bigdatamart_train.csv')
ds_train.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
ds_test =pd.read_csv('bigdatamart_test.csv')
ds_test.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# ...

# %%
print(ds_train.shape)
print(ds_test.shape)
# Out:
# (8523, 12)
# (5681, 11)

# %%
ds_train.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# ...

# %%
ds_test.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 5676           FDB58         10.5          Regular         0.013496
# 5677           FDD47          7.6          Regular         0.142991
# 5678           NCO17         10.0          Low Fat         0.073529
# 5679           FDJ26         15.3          Regular         0.000000
# 5680           FDU37          9.5          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 5676         Snack Foods  141.3154            OUT046
# 5677       Starchy Foods  169.1448            OUT018
# 5678  Health and Hygiene  118.7440            OUT045
# 5679              Canned  214.6218            OUT017
# 5680              Canned   79.7960            OUT045
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 5676                       1997       Small               Tier 1
# 5677                       2009      Medium               Tier 3
# ...

# %%
ds_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 11 columns):
# Item_Identifier              5681 non-null object
# Item_Weight                  4705 non-null float64
# Item_Fat_Content             5681 non-null object
# Item_Visibility              5681 non-null float64
# Item_Type                    5681 non-null object
# Item_MRP                     5681 non-null float64
# Outlet_Identifier            5681 non-null object
# Outlet_Establishment_Year    5681 non-null int64
# Outlet_Size                  4075 non-null object
# Outlet_Location_Type         5681 non-null object
# Outlet_Type                  5681 non-null object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 488.3+ KB

# %%
ds_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
# Item_Identifier              8523 non-null object
# Item_Weight                  7060 non-null float64
# Item_Fat_Content             8523 non-null object
# Item_Visibility              8523 non-null float64
# Item_Type                    8523 non-null object
# Item_MRP                     8523 non-null float64
# Outlet_Identifier            8523 non-null object
# Outlet_Establishment_Year    8523 non-null int64
# Outlet_Size                  6113 non-null object
# Outlet_Location_Type         8523 non-null object
# Outlet_Type                  8523 non-null object
# Item_Outlet_Sales            8523 non-null float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
ds_train=pd.DataFrame(ds_train)

# %%
ds_train.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
ds_test.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# dtype: object

# %%
print(ds_train.isnull().sum())
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
print(ds_test.isnull().sum())
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
import seaborn as sns
sns.heatmap(ds_train.isnull())

# %%
sns.heatmap(ds_test.isnull())

# %%
ds_train.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
ds_test.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year
# count  4705.000000      5681.000000  5681.000000                5681.000000
# mean     12.695633         0.065684   141.023273                1997.828903
# std       4.664849         0.051252    61.809091                   8.372256
# min       4.555000         0.000000    31.990000                1985.000000
# 25%       8.645000         0.027047    94.412000                1987.000000
# 50%      12.500000         0.054154   141.415400                1999.000000
# 75%      16.700000         0.093463   186.026600                2004.000000
# max      21.350000         0.323637   266.588400                2009.000000

# %%
ds_train_new=ds_train.drop(['Outlet_Establishment_Year','Outlet_Size' ,'Outlet_Location_Type' ,'Outlet_Type','Item_Weight'],axis=1)

# %%
ds_train_new.head()
# Out:
#   Item_Identifier Item_Fat_Content  Item_Visibility              Item_Type  \
# 0           FDA15          Low Fat         0.016047                  Dairy
# 1           DRC01          Regular         0.019278            Soft Drinks
# 2           FDN15          Low Fat         0.016760                   Meat
# 3           FDX07          Regular         0.000000  Fruits and Vegetables
# 4           NCD19          Low Fat         0.000000              Household
#
#    Item_MRP Outlet_Identifier  Item_Outlet_Sales
# 0  249.8092            OUT049          3735.1380
# 1   48.2692            OUT018           443.4228
# 2  141.6180            OUT049          2097.2700
# 3  182.0950            OUT010           732.3800
# 4   53.8614            OUT013           994.7052

# %%
ds_test_new=ds_test.drop(['Outlet_Establishment_Year','Outlet_Size' ,'Outlet_Location_Type' ,'Outlet_Type','Item_Weight'],axis=1)

# %%
ds_test_new.head()
# Out:
#   Item_Identifier Item_Fat_Content  Item_Visibility    Item_Type  Item_MRP  \
# 0           FDW58          Low Fat         0.007565  Snack Foods  107.8622
# 1           FDW14              reg         0.038428        Dairy   87.3198
# 2           NCN55          Low Fat         0.099575       Others  241.7538
# 3           FDQ58          Low Fat         0.015388  Snack Foods  155.0340
# 4           FDY38          Regular         0.118599        Dairy  234.2300
#
#   Outlet_Identifier
# 0            OUT049
# 1            OUT017
# 2            OUT010
# 3            OUT017
# 4            OUT027

# %%
ds_train_new1=ds_train_new.drop(['Item_Visibility','Item_MRP','Item_Outlet_Sales'],axis=1)

# %%
ds_train_new1.head()
# Out:
#   Item_Identifier Item_Fat_Content              Item_Type Outlet_Identifier
# 0           FDA15          Low Fat                  Dairy            OUT049
# 1           DRC01          Regular            Soft Drinks            OUT018
# 2           FDN15          Low Fat                   Meat            OUT049
# 3           FDX07          Regular  Fruits and Vegetables            OUT010
# 4           NCD19          Low Fat              Household            OUT013

# %%
ds_train_new.drop(['Item_Identifier','Item_Fat_Content','Item_Type','Outlet_Identifier'],axis=1,inplace=True)

# %%
ds_train_new.head()
# Out:
#    Item_Visibility  Item_MRP  Item_Outlet_Sales
# 0         0.016047  249.8092          3735.1380
# 1         0.019278   48.2692           443.4228
# 2         0.016760  141.6180          2097.2700
# 3         0.000000  182.0950           732.3800
# 4         0.000000   53.8614           994.7052

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in ds_train_new1.columns:
    ds_train_new1[i]=le.fit_transform(ds_train_new1[i])

# %%
ds_train_new1.head()
# Out:
#    Item_Identifier  Item_Fat_Content  Item_Type  Outlet_Identifier
# 0              156                 1          4                  9
# 1                8                 2         14                  3
# 2              662                 1         10                  9
# 3             1121                 2          6                  0
# 4             1297                 1          9                  1

# %%
ds_train_new =pd.concat([ds_train_new1,ds_train_new],axis=1)

# %%
ds_train_new.head()
# Out:
#    Item_Identifier  Item_Fat_Content  Item_Type  Outlet_Identifier  \
# 0              156                 1          4                  9
# 1                8                 2         14                  3
# 2              662                 1         10                  9
# 3             1121                 2          6                  0
# 4             1297                 1          9                  1
#
#    Item_Visibility  Item_MRP  Item_Outlet_Sales
# 0         0.016047  249.8092          3735.1380
# 1         0.019278   48.2692           443.4228
# 2         0.016760  141.6180          2097.2700
# 3         0.000000  182.0950           732.3800
# 4         0.000000   53.8614           994.7052

# %%
ds_test_new.head()
# Out:
#   Item_Identifier Item_Fat_Content  Item_Visibility    Item_Type  Item_MRP  \
# 0           FDW58          Low Fat         0.007565  Snack Foods  107.8622
# 1           FDW14              reg         0.038428        Dairy   87.3198
# 2           NCN55          Low Fat         0.099575       Others  241.7538
# 3           FDQ58          Low Fat         0.015388  Snack Foods  155.0340
# 4           FDY38          Regular         0.118599        Dairy  234.2300
#
#   Outlet_Identifier
# 0            OUT049
# 1            OUT017
# 2            OUT010
# 3            OUT017
# 4            OUT027

# %%
ds_test_new1=ds_test_new.drop(['Item_Visibility','Item_MRP'],axis=1)

# %%
ds_test_new1.head()
# Out:
#   Item_Identifier Item_Fat_Content    Item_Type Outlet_Identifier
# 0           FDW58          Low Fat  Snack Foods            OUT049
# 1           FDW14              reg        Dairy            OUT017
# 2           NCN55          Low Fat       Others            OUT010
# 3           FDQ58          Low Fat  Snack Foods            OUT017
# 4           FDY38          Regular        Dairy            OUT027

# %%
ds_test_new.drop(['Item_Identifier','Item_Fat_Content','Item_Type','Outlet_Identifier'],axis=1,inplace=True)

# %%
ds_test_new.head()
# Out:
#    Item_Visibility  Item_MRP
# 0         0.007565  107.8622
# 1         0.038428   87.3198
# 2         0.099575  241.7538
# 3         0.015388  155.0340
# 4         0.118599  234.2300

# %%
le=LabelEncoder()
for i in ds_test_new1.columns:
    ds_test_new1[i]=le.fit_transform(ds_test_new1[i])

# %%
ds_test_new1.head()
# Out:
#    Item_Identifier  Item_Fat_Content  Item_Type  Outlet_Identifier
# 0             1103                 1         13                  9
# 1             1067                 4          4                  2
# 2             1406                 1         11                  0
# 3              809                 1         13                  2
# 4             1184                 2          4                  5

# %%
ds_test_new=pd.concat([ds_test_new1,ds_test_new],axis=1)

# %%
ds_test_new.head()
# Out:
#    Item_Identifier  Item_Fat_Content  Item_Type  Outlet_Identifier  \
# 0             1103                 1         13                  9
# 1             1067                 4          4                  2
# 2             1406                 1         11                  0
# 3              809                 1         13                  2
# 4             1184                 2          4                  5
#
#    Item_Visibility  Item_MRP
# 0         0.007565  107.8622
# 1         0.038428   87.3198
# 2         0.099575  241.7538
# 3         0.015388  155.0340
# 4         0.118599  234.2300

# %%
ds_train_new.head()
# Out:
#    Item_Identifier  Item_Fat_Content  Item_Type  Outlet_Identifier  \
# 0              156                 1          4                  9
# 1                8                 2         14                  3
# 2              662                 1         10                  9
# 3             1121                 2          6                  0
# 4             1297                 1          9                  1
#
#    Item_Visibility  Item_MRP  Item_Outlet_Sales
# 0         0.016047  249.8092          3735.1380
# 1         0.019278   48.2692           443.4228
# 2         0.016760  141.6180          2097.2700
# 3         0.000000  182.0950           732.3800
# 4         0.000000   53.8614           994.7052

# %%
ds_train_new.corr()
# Out:
#                    Item_Identifier  Item_Fat_Content  Item_Type  \
# Item_Identifier           1.000000         -0.098114  -0.017973
# Item_Fat_Content         -0.098114          1.000000  -0.115958
# Item_Type                -0.017973         -0.115958   1.000000
# Outlet_Identifier        -0.008602         -0.002357   0.001656
# Item_Visibility          -0.025482          0.034042  -0.035249
# Item_MRP                  0.012853         -0.000876   0.032651
# Item_Outlet_Sales         0.002869          0.009800   0.017048
#
#                    Outlet_Identifier  Item_Visibility  Item_MRP  \
# Item_Identifier            -0.008602        -0.025482  0.012853
# Item_Fat_Content           -0.002357         0.034042 -0.000876
# Item_Type                   0.001656        -0.035249  0.032651
# Outlet_Identifier           1.000000        -0.100439  0.003319
# Item_Visibility            -0.100439         1.000000 -0.001315
# Item_MRP                    0.003319        -0.001315  1.000000
# ...

# %%
sns.heatmap(ds_train_new.corr(),annot=True)

# %%
import matplotlib.pyplot as plt
for i in ds_train_new.columns:
    plt.boxplot(ds_train_new[i])
    print('\n')
    print(i)
    plt.show()
# Out:
# Item_Identifier
# Item_Fat_Content
# Item_Type
# Outlet_Identifier
# Item_Visibility
# Item_MRP
# Item_Outlet_Sales

# %%
for i in ds_train_new.columns:
    print(i)
    sns.distplot(ds_train_new[i],bins=10)
    print('\n')
    plt.show()
# Out:
# Item_Identifier
# Item_Fat_Content
# Item_Type
# Outlet_Identifier
# Item_Visibility
# Item_MRP
# Item_Outlet_Sales

# %%
ds_train_new.hist(figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000024009352788>,
# ...
#       dtype=object)

# %%
sns.pairplot(ds_train_new)

# %%
import numpy as np
from scipy.stats import zscore
z=np.abs(zscore(ds_train_new))
print(z.shape)
ds_new=ds_train_new.loc[(abs(z)<3).all(axis=1)]
print(ds_new.shape)
# Out:
# (8523, 7)
# (8222, 7)

# %%
ds_new.skew()
# Out:
# Item_Identifier     -0.011945
# Item_Fat_Content     0.291106
# Item_Type            0.094578
# Outlet_Identifier   -0.067611
# Item_Visibility      0.794506
# Item_MRP             0.139153
# Item_Outlet_Sales    0.877476
# dtype: float64

# %%
ds_new.Item_Visibility=np.sqrt(ds_new.Item_Visibility )

# %%
ds_new.skew()
# Out:
# Item_Identifier     -0.011945
# Item_Fat_Content     0.291106
# Item_Type            0.094578
# Outlet_Identifier   -0.067611
# Item_Visibility     -0.244803
# Item_MRP             0.139153
# Item_Outlet_Sales    0.877476
# dtype: float64

# %%
x=ds_new.drop(['Item_Outlet_Sales'],axis=1)
print(x.shape)
y=ds_new['Item_Outlet_Sales']
print(y.shape)
# Out:
# (8222, 6)
# (8222,)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[-1.38525904, -0.58389405, -0.76912722,  1.49679593, -0.99947883,
#          1.77157705],
#        [-1.71298557,  1.17592152,  1.6114495 , -0.61635797, -0.88236696,
#         -1.48458116],
#        [-0.26478859, -0.58389405,  0.65921881,  1.49679593, -0.97269604,
#          0.02359817],
#        ...,
#        [ 1.2741975 , -0.58389405,  0.18310347,  0.44021898, -0.41332537,
#         -0.8891666 ],
#        [-0.22271559,  1.17592152,  1.37339183, -0.61635797,  1.44900224,
#         -0.59817715],
#        [-1.6199821 , -0.58389405,  1.6114495 ,  1.14460361, -0.1797873 ,
#         -1.04516298]])

# %%
def maxr2_score(rg,x,y):
    max_r_score =0
    for r_state in range(42,100):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
        rg.fit(x_train,y_train)
        pred=rg.predict(x_test)
        r2_scr=r2_score(y_test,pred)
       # print('r2 score corrasponding to',r_state,'is',r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print('max r2 score corrasponding to ',final_r_state,'is',max_r_score)
    return final_r_state

# %%
lg=LinearRegression()
r_state=maxr2_score(lg,x,y)
print('Mean r2 score for linear Regression:',cross_val_score(lg,x,y,cv=5,scoring='r2').mean())
print('stander deviation in r2 score for linear Regression',cross_val_score(lg,x,y,cv=5,scoring='r2').std())
# Out:
# max r2 score corrasponding to  42 is 0.37788042752886986
# Mean r2 score for linear Regression: 0.35288333723350307
# stander deviation in r2 score for linear Regression 0.012345527250673333

# %%
neighbors={'n_neighbors':range(1,30)}
knr=KNeighborsRegressor()
gknr=GridSearchCV(knr,neighbors,cv=10)
gknr.fit(x,y)
gknr.best_params_
# Out:
# {'n_neighbors': 21}

# %%
knr=KNeighborsRegressor(n_neighbors=21)
r_state=maxr2_score(knr,x,y)
print('Mean r2 score for KNN Regression:',cross_val_score(knr,x,y,cv=5,scoring='r2').mean())
print('stander deviation r2 score for KNN Regression:',cross_val_score(knr,x,y,cv=5,scoring='r2').std())
# Out:
# max r2 score corrasponding to  86 is 0.39783854226100235
# Mean r2 score for KNN Regression: 0.3632031642155904
# stander deviation r2 score for KNN Regression: 0.009012112718074502

# %%
from sklearn.linear_model import Lasso
lsreg=Lasso()
parameters={"alpha":[0.001,0.01,0.1,1]}
clf=GridSearchCV(lsreg,parameters,cv=10)
clf.fit(x,y)
clf.best_params_
# Out:
# {'alpha': 1}

# %%
#let check max r2 score when we use lasso
lsreg=Lasso(alpha=1)
r_state=maxr2_score(lsreg,x,y)
print('Mean r2 score for Lasso Regration',cross_val_score(lsreg,x,y,cv=5,scoring='r2').mean())
print('stander deviation in r2 score for Lasso Regretion',cross_val_score(lsreg,x,y,cv=5,scoring='r2').std())
# Out:
# max r2 score corrasponding to  42 is 0.3778201135367022
# Mean r2 score for Lasso Regration 0.35292791970242493
# stander deviation in r2 score for Lasso Regretion 0.012288887653964796

# %%
ada_reg =AdaBoostRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000],"base_estimator":[lg,lsreg,DecisionTreeRegressor()]}
clf=GridSearchCV(ada_reg,parameters,cv=5)
clf.fit(x,y)
clf.best_params_
# Out:
# {'base_estimator': DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                        max_leaf_nodes=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        presort=False, random_state=None, splitter='best'),
#  'learning_rate': 0.001,
#  'n_estimators': 500}

# %%
ada_reg=AdaBoostRegressor(base_estimator=DecisionTreeRegressor(),learning_rate=0.001,n_estimators=500)
print('Mean r2 score for ada Boosting Regration:',cross_val_score(ada_reg,x,y,cv=5,scoring='r2').mean())
print('Mean r2 score for ada Boosting Regration:',cross_val_score(ada_reg,x,y,cv=5,scoring='r2').std())
# Out:
# Mean r2 score for ada Boosting Regration: 0.46780513989565675
# Mean r2 score for ada Boosting Regration: 0.02056527848818697

# %%
r_state=maxr2_score(ada_reg,x,y)
# Out:
# max r2 score corrasponding to  88 is 0.5360109677724982

# %%
#finalizing the models AdaBoostRegressor
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=88,test_size=0.20)
adb=AdaBoostRegressor(base_estimator=DecisionTreeRegressor(),learning_rate=0.001,n_estimators=500)
adb.fit(x_train,y_train)
y_pred=adb.predict(x_test)
print(y_pred)
print(y_test)
# Out:
# [1470.0864  198.4084 1022.6688 ... 1340.2554 4950.8888  645.1602]
# 4492    2436.8280
# 1914     515.3292
# 5657     818.9340
# 4345     522.6530
# 3174    3528.7400
#           ...
# 6051    5779.1440
# 7049    3199.8348
# 3553     731.0484
# 1483    3579.3408
# 6892     247.0118
# Name: Item_Outlet_Sales, Length: 1645, dtype: float64

# %%
ds_test_new.head()
# Out:
#    Item_Identifier  Item_Fat_Content  Item_Type  Outlet_Identifier  \
# 0             1103                 1         13                  9
# 1             1067                 4          4                  2
# 2             1406                 1         11                  0
# 3              809                 1         13                  2
# 4             1184                 2          4                  5
#
#    Item_Visibility  Item_MRP
# 0         0.007565  107.8622
# 1         0.038428   87.3198
# 2         0.099575  241.7538
# 3         0.015388  155.0340
# 4         0.118599  234.2300

# %%
ds_test_new.shape
# Out:
# (5681, 6)

# %%
pred_test_data=adb.predict(ds_test_new)

# %%
print(pred_test_data)
# Out:
# [4210.5192 4210.5192 3297.7074 ... 4210.5192 4210.5192 4210.5192]

# %%
pred_test_data=pd.DataFrame(pred_test_data)
pred_test_data.to_csv('pred_test_data.csv')
pred_test_data
# Out:
#               0
# 0     4210.5192
# 1     4210.5192
# 2     3297.7074
# 3     4210.5192
# 4     4210.5192
# ...         ...
# 5676  4210.5192
# 5677  4229.1616
# 5678  4210.5192
# 5679  4210.5192
# 5680  4210.5192
#
# [5681 rows x 1 columns]

# %%
#saving model
joblib.dump(adb,'bigdatamart_project_adb.obj')
# Out:
# ['bigdatamart_project_adb.obj']
