# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.externals import joblib
import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
ds=pd.read_csv('world_happiness.csv')

# %%
ds.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %%
ds.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# 154                   0.31910  0.48450                        0.08010
# 155                   0.72193  0.15684                        0.18906
# 156                   0.22396  0.11850                        0.10062
# 157                   0.28443  0.36453                        0.10731
#
#      Generosity  Dystopia Residual
# 153     0.22628            0.67042
# 154     0.18260            1.63328
# 155     0.47179            0.32858
# 156     0.19727            1.83302
# 157     0.16681            1.56726

# %%
ds.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
# Country                          158 non-null object
# Region                           158 non-null object
# Happiness Rank                   158 non-null int64
# Happiness Score                  158 non-null float64
# Standard Error                   158 non-null float64
# Economy (GDP per Capita)         158 non-null float64
# Family                           158 non-null float64
# Health (Life Expectancy)         158 non-null float64
# Freedom                          158 non-null float64
# Trust (Government Corruption)    158 non-null float64
# Generosity                       158 non-null float64
# Dystopia Residual                158 non-null float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 14.9+ KB

# %%
ds.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
ds.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# 50%                    0.910245    1.029510                  0.696705
# 75%                    1.158448    1.214405                  0.811013
# max                    1.690420    1.402230                  1.025250
#
#           Freedom  Trust (Government Corruption)  Generosity  \
# count  158.000000                     158.000000  158.000000
# mean     0.428615                       0.143422    0.237296
# std      0.150693                       0.120034    0.126685
# min      0.000000                       0.000000    0.000000
# 25%      0.328330                       0.061675    0.150553
# 50%      0.435515                       0.107220    0.216130
# 75%      0.549092                       0.180255    0.309883
# max      0.669730                       0.551910    0.795880
#
#        Dystopia Residual
# count         158.000000
# mean            2.098977
# std             0.553550
# min             0.328580
# 25%             1.759410
# 50%             2.095415
# 75%             2.462415
# max             3.602140

# %%
ds['Happiness Score'].value_counts()
# Out:
# 5.192    2
# 4.642    1
# 5.098    1
# 5.129    1
# 5.889    1
#         ..
# 4.252    1
# 4.633    1
# 3.931    1
# 7.200    1
# 6.750    1
# Name: Happiness Score, Length: 157, dtype: int64

# %%
ds.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
sns.heatmap(ds.isnull())

# %%
ds_new =ds.drop(['Country','Region','Happiness Rank','Standard Error'],axis=1)

# %%
ds_new.head()
# Out:
#    Happiness Score  Economy (GDP per Capita)   Family  \
# 0            7.587                   1.39651  1.34951
# 1            7.561                   1.30232  1.40223
# 2            7.527                   1.32548  1.36058
# 3            7.522                   1.45900  1.33095
# 4            7.427                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %%
ds_new.corr()
# Out:
#                                Happiness Score  Economy (GDP per Capita)  \
# Happiness Score                       1.000000                  0.780966
# Economy (GDP per Capita)              0.780966                  1.000000
# Family                                0.740605                  0.645299
# Health (Life Expectancy)              0.724200                  0.816478
# Freedom                               0.568211                  0.370300
# Trust (Government Corruption)         0.395199                  0.307885
# Generosity                            0.180319                 -0.010465
# Dystopia Residual                     0.530474                  0.040059
#
#                                  Family  Health (Life Expectancy)   Freedom  \
# Happiness Score                0.740605                  0.724200  0.568211
# Economy (GDP per Capita)       0.645299                  0.816478  0.370300
# Family                         1.000000                  0.531104  0.441518
# Health (Life Expectancy)       0.531104                  1.000000  0.360477
# Freedom                        0.441518                  0.360477  1.000000
# Trust (Government Corruption)  0.205605                  0.248335  0.493524
# Generosity                     0.087513                  0.108335  0.373916
# Dystopia Residual              0.148117                  0.018979  0.062783
#
#                                Trust (Government Corruption)  Generosity  \
# Happiness Score                                     0.395199    0.180319
# Economy (GDP per Capita)                            0.307885   -0.010465
# Family                                              0.205605    0.087513
# Health (Life Expectancy)                            0.248335    0.108335
# Freedom                                             0.493524    0.373916
# Trust (Government Corruption)                       1.000000    0.276123
# Generosity                                          0.276123    1.000000
# Dystopia Residual                                  -0.033105   -0.101301
#
#                                Dystopia Residual
# Happiness Score                         0.530474
# Economy (GDP per Capita)                0.040059
# Family                                  0.148117
# Health (Life Expectancy)                0.018979
# Freedom                                 0.062783
# Trust (Government Corruption)          -0.033105
# Generosity                             -0.101301
# Dystopia Residual                       1.000000

# %%
plt.figure(figsize=(10,10))
sns.heatmap(ds_new.corr(),annot=True)

# %%
for i in ds_new.columns:
    if i !='Happiness Score':
        print(i)
        sns.lineplot(x=ds_new['Happiness Score'],y=ds_new[i],data=ds_new)
        print('\n')
        plt.show()
# Out:
# Economy (GDP per Capita)
# Family
# Health (Life Expectancy)
# Freedom
# Trust (Government Corruption)
# Generosity
# Dystopia Residual

# %%
for i in ds_new.columns:
    plt.boxplot(x=ds_new[i])
    print(i)
    print('\n')
    plt.show()
# Out:
# Happiness Score
# Economy (GDP per Capita)
# Family
# Health (Life Expectancy)
# Freedom
# Trust (Government Corruption)
# Generosity
# Dystopia Residual

# %%
for i in ds_new.columns:
    print(i)
    sns.distplot(ds_new[i],bins=10)
    print('\n')
    plt.show()
# Out:
# Happiness Score
# Economy (GDP per Capita)
# Family
# Health (Life Expectancy)
# Freedom
# Trust (Government Corruption)
# Generosity
# Dystopia Residual

# %%
ds_new.hist(figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000219F14D8888>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000219F047CDC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000219F16CB348>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000219F00F5D08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000219F015DE08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000219F002AF08>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000219F007F048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000219F1611FC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000219F15E4D08>]],
#       dtype=object)

# %%
sns.pairplot(ds_new)

# %%
#check the skewness of data
ds_new.skew()
# Out:
# Happiness Score                  0.097769
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
#removing outliers
z=np.abs(zscore(ds_new))
print(z.shape)
ds_new=ds_new.loc[(abs(z)<3).all(axis=1)]
print(ds_new.shape)
# Out:
# (158, 8)
# (152, 8)

# %%
ds_new.skew()
# Out:
# Happiness Score                  0.165587
# Economy (GDP per Capita)        -0.401110
# Family                          -0.815356
# Health (Life Expectancy)        -0.733453
# Freedom                         -0.406211
# Trust (Government Corruption)    1.287270
# Generosity                       0.646579
# Dystopia Residual               -0.045578
# dtype: float64

# %%
ds_new['Trust (Government Corruption)']=np.sqrt(ds_new['Trust (Government Corruption)'])
ds_new['Generosity']=np.sqrt(ds_new['Generosity'])

# %%
ds_new.skew()
# Out:
# Happiness Score                  0.165587
# Economy (GDP per Capita)        -0.401110
# Family                          -0.815356
# Health (Life Expectancy)        -0.733453
# Freedom                         -0.406211
# Trust (Government Corruption)    0.447061
# Generosity                      -0.303388
# Dystopia Residual               -0.045578
# dtype: float64

# %%
x=ds_new.drop(['Happiness Score'],axis=1)
print(x.shape)
y=ds_new['Happiness Score']
print(y.shape)
# Out:
# (152, 7)
# (152,)

# %%
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 1.38120592,  1.36173566,  1.24883532, ...,  2.0893242 ,
#          0.62333814,  0.7472976 ],
#        [ 1.13920813,  1.57273597,  1.27511639, ...,  0.23434928,
#          1.51525589,  1.10115487],
#        [ 1.19871199,  1.40604092,  0.97499558, ...,  2.41340994,
#          0.92777707,  0.69873159],
#        ...,
#        [-1.38508144, -2.82729288, -1.36729975, ..., -0.2047835 ,
#          1.0814899 , -0.33610398],
#        [-1.47030351, -2.62313647, -1.30272457, ..., -0.40088019,
#         -0.28170209, -0.94714645],
#        [-2.16746989, -2.37495496, -1.69279963, ..., -0.16756572,
#         -0.15199491, -0.56432974]])

# %%
def maxr2_score(rg,x,y):
    max_r_score =0
    for r_state in range(42,100):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
        rg.fit(x_train,y_train)
        pred=rg.predict(x_test)
        r2_scr=r2_score(y_test,pred)
       # print('r2 score corrasponding to',r_state,'is',r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print('max r2 score corrasponding to ',final_r_state,'is',max_r_score)
    return final_r_state

# %%
lg=LinearRegression()
r_state=maxr2_score(lg,x,y)
print('Mean r2 score for linear Regression:',cross_val_score(lg,x,y,cv=5,scoring='r2').mean())
print('stander deviation in r2 score for linear Regression',cross_val_score(lg,x,y,cv=5,scoring='r2').std())
# Out:
# max r2 score corrasponding to  90 is 0.9996209543470161
# Mean r2 score for linear Regression: 0.953029136808856
# stander deviation in r2 score for linear Regression 0.03248744070698704

# %%
neighbors={'n_neighbors':range(1,30)}
knr=KNeighborsRegressor()
gknr=GridSearchCV(knr,neighbors,cv=10)
gknr.fit(x,y)
gknr.best_params_
# Out:
# {'n_neighbors': 8}

# %%
knr=KNeighborsRegressor(n_neighbors=8)
r_state=maxr2_score(knr,x,y)
print('Mean r2 score for KNN Regression:',cross_val_score(knr,x,y,cv=5,scoring='r2').mean())
print('stander deviation r2 score for KNN Regression:',cross_val_score(knr,x,y,cv=5,scoring='r2').std())
# Out:
# max r2 score corrasponding to  99 is 0.9635920215579749
# Mean r2 score for KNN Regression: -4.866624563161504
# stander deviation r2 score for KNN Regression: 3.275563116374797

# %%
from sklearn.linear_model import Lasso
lsreg=Lasso()
parameters={"alpha":[0.001,0.01,0.1,1]}
clf=GridSearchCV(lsreg,parameters,cv=10)
clf.fit(x,y)
clf.best_params_
# Out:
# {'alpha': 0.001}

# %%
#let check max r2 score when we use lasso
lsreg=Lasso(alpha=0.001)
r_state=maxr2_score(lsreg,x,y)
print('Mean r2 score for Lasso Regration',cross_val_score(lsreg,x,y,cv=5,scoring='r2').mean())
print('stander deviation in r2 score for Lasso Regretion',cross_val_score(lsreg,x,y,cv=5,scoring='r2').std())
# Out:
# max r2 score corrasponding to  90 is 0.9996275662607351
# Mean r2 score for Lasso Regration 0.9520678049024134
# stander deviation in r2 score for Lasso Regretion 0.03140675549335933

# %%
ada_reg =AdaBoostRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000],"base_estimator":[lg,lsreg,DecisionTreeRegressor()]}
clf=GridSearchCV(ada_reg,parameters,cv=5)
clf.fit(x,y)
clf.best_params_
# Out:
# {'base_estimator': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  'learning_rate': 0.01,
#  'n_estimators': 100}

# %%
ada_reg=AdaBoostRegressor(base_estimator=lsreg,learning_rate=0.01,n_estimators=100)
print('Mean r2 score for ada Boosting Regration:',cross_val_score(ada_reg,x,y,cv=5,scoring='r2').mean())
print('Mean r2 score for ada Boosting Regration:',cross_val_score(ada_reg,x,y,cv=5,scoring='r2').std())
# Out:
# Mean r2 score for ada Boosting Regration: 0.9520504494302772
# Mean r2 score for ada Boosting Regration: 0.02989362244087571

# %%
r_state=maxr2_score(ada_reg,x,y)
# Out:
# max r2 score corrasponding to  90 is 0.999568710246974

# %%
#finalizing the models Linear Regression
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=90,test_size=0.20)
lg=LinearRegression()
lg.fit(x_train,y_train)
y_pred=lg.predict(x_test)
print(y_pred)
print(y_test)
# Out:
# [5.00026432 6.94333509 7.01329824 4.6633027  3.99984799 6.03199646
#  5.1357395  4.58329522 5.90888277 4.35456535 4.19380177 6.80635045
#  4.48659185 4.45808632 6.14572092 3.33994953 4.06851    6.79320065
#  5.24145999 5.70367151 4.86853012 3.66578672 3.6638599  6.294542
#  4.97124313 5.48971174 4.69237087 4.62312914 2.91147261 6.8272802
#  6.50067153]
# 91     5.013
# 16     6.946
# 15     6.983
# 112    4.642
# 138    3.989
# 45     5.987
# 86     5.123
# 117    4.550
# 50     5.890
# 125    4.369
# 133    4.218
# 22     6.810
# 118    4.518
# 123    4.436
# 42     6.123
# 154    3.340
# 135    4.077
# 25     6.750
# 82     5.192
# 64     5.709
# 99     4.874
# 150    3.655
# 148    3.667
# 36     6.302
# 93     4.971
# 70     5.477
# 109    4.686
# 114    4.610
# 156    2.905
# 24     6.786
# 30     6.505
# Name: Happiness Score, dtype: float64

# %%
print('RMSE is: ',np.sqrt(mean_squared_error(y_test,y_pred)))
print('r2_score is:',r2_score(y_test,y_pred))
# Out:
# RMSE is:  0.021903553429767828
# r2_score is: 0.9996209543470161

# %%
#saving model
joblib.dump(lg,'worldhappiness_lg.obj')
# Out:
# ['worldhappiness_lg.obj']
